# %% [markdown]
# # Reinforcement Learning Sprint Challenge - play Taxi
#
# For the sprint challenge, we will apply the techniques we have learned to play
# [Taxi](https://gym.openai.com/envs/Taxi-v2/), an environment in the OpenAI Gym.
# In this task the agent controls a taxi that can navigate between four locations.
# The goal is to pick up a passenger from one location and drop them off to
# another. You get 20 points for each successful drop off, but lose 1 point for
# each step you take, and additionally there is a 10 point penalty for illegal
# pick-up/drop-off actions.
#
# You can create the environment and watch a random agent play with this code:
#
# ```python
# import gym
#
# env = gym.make('Taxi-v2')
# state = env.reset()
# env.render()
#
# total_reward = 0
# done = False
# while not done:
#     state, reward, done, info = env.step(env.action_space.sample())
#     total_reward += reward
#     env.render()
#
# print('Total reward:', total_reward)
# ```
#
# You'll see that a random agent doesn't do very well - in a trial run the score
# reached -713 before the environment terminated.

# %%
import gym

env = gym.make('Taxi-v2')
state = env.reset()
env.render()
print('^^ Initial State ^^')

counterrr = 0
total_reward = 0
done = False
while not done:
    print('\n\n\\/\\/\\/\\/\\/\\/\n')
    
    state, reward, done, info = env.step(env.action_space.sample())
    
    total_reward += reward
    counterrr += 1
    
    env.render()
    print(state, reward, done, info)
    
    print('\n<<^^^^^^^^^^>>\n\n')

print('Total reward: ', total_reward)
print('Steps: ', counterrr)
# Out:
# /Users/darwinm/Documents/LambdaSchool/14/gym/gym/__init__.py:22: UserWarning: DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.
#   warnings.warn('DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.')
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# ^^ Initial State ^^
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 22 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 2 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 2 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 2 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 18 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 18 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 18 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 18 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 2 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 2 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 22 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 22 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 22 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 22 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 22 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 22 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 22 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 122 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 122 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 102 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 2 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 102 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 102 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 122 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 122 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 102 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 102 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 202 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 302 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 402 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 402 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 402 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 402 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 402 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 402 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 402 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 402 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 402 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 302 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 302 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 302 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 202 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 202 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 222 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 322 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 322 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 322 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 422 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 322 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 322 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 222 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 242 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 262 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 262 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 262 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 162 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 62 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 42 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 62 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 42 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 62 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 42 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 62 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 162 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 162 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 142 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 162 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 162 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 62 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 42 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 142 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 142 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 142 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 242 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 242 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 242 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 262 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 262 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 262 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 262 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 362 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 382 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 382 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 382 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 282 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 282 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 282 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 382 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 262 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 262 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 262 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 262 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 262 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 262 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 282 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 262 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 362 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 382 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 462 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 462 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 482 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 382 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 382 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 382 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 282 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 262 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 242 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 242 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 142 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 162 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 182 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 182 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 82 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 82 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 82 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 82 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 62 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 162 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 142 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 242 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 242 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 222 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 122 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 122 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 222 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 202 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 202 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 302 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 302 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 302 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 302 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 302 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 302 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 302 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 302 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 202 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 222 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 242 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 222 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 122 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 142 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 142 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 42 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 62 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 82 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 62 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 42 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 142 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 162 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 162 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 262 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 242 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 342 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 342 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 242 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 242 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 262 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 362 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 262 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 282 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 282 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 282 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 182 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 182 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 182 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 282 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 182 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# 182 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# 162 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 162 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# 62 -1 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# 62 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 62 -10 False {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
#
#
# \/\/\/\/\/\/
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# 162 -1 True {'prob': 1.0}
#
# <<^^^^^^^^^^>>
#
#
# Total reward:  -713
# Steps:  200

# %%
### Random reward == -713
print('Total reward: ', total_reward)
print('Steps: ', counterrr)
print('Average Reward: ', (total_reward/counterrr))
# Out:
# Total reward:  -713
# Steps:  200
# Average Reward:  -3.565

# %% [markdown]
# ## Instructions
#
# Make a Python notebook where you work on the below goals. You can use whatever
# environment you wish to develop, but for turning in you should add the file to
# the `ML-Reinforcement-Learning` repository in the `sprintchallenge/` directory.
# Add, commit, push, and it will appear in your already open pull request.
#
# The goals involve trying to beat a score in Taxi - be sure to measure the score
# of your approach after it is trained, and not during the training. This snippet
# measures performance (run a simulation repeatedly and average total rewards):
#
# ```python
# episodes = 1000
# rewards = []
# max_steps = 99
#
# for episode in range(episodes):
#     state = env.reset()  # Assuming you already have env created as above
#     total_rewards = 0
#
#     for step in range(max_steps):
#         action = env.action_space.sample() # TODO your policy here!
#         state, reward, done, info = env.step(env.action_space.sample())
#         total_rewards += reward
#         if done:
#             break
#     rewards.append(total_rewards)
#
# print('Average score over time:', sum(rewards) / episodes)
# ```

# %%
print('Observation Space: ', env.observation_space)
print('Action Space:      ', env.action_space)
# Out:
# Observation Space:  Discrete(500)
# Action Space:       Discrete(6)

# %%
import numpy as np
import random
from collections import defaultdict

# %%
### TheHYPErPARAMETERS ###

total_episodes = 1000
learning_rate = 0.9
max_steps = 99
gamma = 0.99


# Exploration Parameters

epsilon = 1.0         # Exploration Rate
max_epsilon = 1.0     # Initial exploration probability
min_epsilon = 0.01    # Minimum exploration probability
decay_rate = 0.01     # Exponential decay rate for exploration

# %%
# %%time

rewards = []

# Learn from the episodes
for episode in range(total_episodes):
    # Reset for a blank slate
    state = env.reset()
    done = False
    total_rewards = 0
    env.render()
    print('^^ initial state ^^')
print('Average score over time:', sum(rewards) / episodes)

for step in range(max_steps):
        taxi_location = state, reward, done, info = env.step(env.action_space.sample())

        print('\n\n\\/\\/\\/\\/\\/\\/\n')
    
        state, reward, done, info = env.step(env.action_space.sample())
    
        total_reward += reward
        counterrr += 1
    
        env.render()
        print(state, reward, done, info)
    
        print('\n<<^^^^^^^^^^>>\n\n')

print('Total reward: ', total_reward)
print('Steps: ', counterrr)

# %%
# this is a dictionary of actions 
qtable_dict = defaultdict(lambda: np.zeros(6))

# %%
# %%time 

env.render()
print('^^ initial state ^^')

episodes = 10000
rewards = []
max_steps = 99
   
for episode in range(episodes):
    state = env.reset()  # Assuming you already have env created as above
    total_rewards = 0

    for step in range(max_steps):
        if random.uniform(0, 1) < epsilon:
            # We explore at this level of epsilon
            action = env.action_space.sample()
        else: 
            # Exploit based on best available rewards
            action = np.argmax(qtable_dict[state])
            
        #action = env.action_space.sample() # TODO your policy here!
        new_state, reward, done, info = env.step(env.action_space.sample())
        
        # update qtable
        qtable_dict[state][action] += learning_rate * (reward + gamma * (np.max(qtable_dict[new_state])) - qtable_dict[state][action])
        
        total_rewards += reward
        state = new_state
        if done:
            break
        # Explore less as we learn    
        epsilon = (min_epsilon + (max_epsilon - min_epsilon) * np.exp(-decay_rate * episode))
    rewards.append(total_rewards)   
    
print('\nAverage score over time:', sum(rewards) / episodes)
print('\nSum of Rewards: ',sum(rewards))
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# ^^ initial state ^^
#
# Average score over time: -385.2214
#
# Sum of Rewards:  -3852214
# CPU times: user 1min 5s, sys: 514 ms, total: 1min 6s
# Wall time: 1min 14s

# %%
qtable_dict = defaultdict(lambda: np.zeros(6))

# %%
### TheHYPErPARAMETERS ###

episodes = 100000
learning_rate = 0.0009
max_steps = 9
gamma = 0.99


# Exploration Parameters

epsilon = 0.7        # Exploration Rate
max_epsilon = 1.0     # Initial exploration probability
min_epsilon = 0.01    # Minimum exploration probability
decay_rate = 0.01     # Exponential decay rate for exploration

# %%
# %%time 

env.render()
print('^^ initial state ^^')

#episodes = 10000
rewards = []
counterrr = 0

   
for episode in range(episodes):
    state = env.reset()  # Assuming you already have env created as above
    total_rewards = 0

    for step in range(max_steps):
        if random.uniform(0, 1) < epsilon:
            # We explore at this level of epsilon
            action = env.action_space.sample()
        else: 
            # Exploit based on best available rewards
            action = np.argmax(qtable_dict[state])
            
        #action = env.action_space.sample() # TODO your policy here!
        new_state, reward, done, info = env.step(env.action_space.sample())
        
        # update qtable
        qtable_dict[state][action] += learning_rate * (reward + gamma * (np.max(qtable_dict[new_state])) - qtable_dict[state][action])
        
        total_rewards += reward
        counterrr += 1
        state = new_state
        if reward == 20:
        #if done:
            break
        # Explore less as we learn    
        epsilon = (min_epsilon + (max_epsilon - min_epsilon) * np.exp(-decay_rate * episode))
    rewards.append(total_rewards)   
    
print('\nAverage score over time:', sum(rewards) / episodes)
print('Counter: ', counterrr)
print('Epsilon: ', epsilon)
print('\nSum of Rewards: ',sum(rewards))
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# ^^ initial state ^^
#
# Average score over time: -35.48007
# Counter:  900000
# Epsilon:  0.01
#
# Sum of Rewards:  -3548007
# CPU times: user 1min 3s, sys: 652 ms, total: 1min 3s
# Wall time: 1min 6s

# %%
print(qtable_dict)
# Out:
# defaultdict(<function <lambda> at 0x1a14d39598>, {288: array([-176.14658751, -176.17186024, -176.11452486, -176.16499972,
#        -176.15388366, -176.18308107]), 388: array([-177.85993325, -177.85927862, -177.84744681, -177.82455216,
#        -177.85828156, -177.88030339]), 268: array([-175.19966918, -175.28745641, -175.22532529, -175.23073531,
#        -175.24805077, -175.22522602]), 368: array([-177.21715876, -177.16124848, -177.20725834, -177.25781783,
#        -177.20253607, -177.20381167]), 188: array([-176.73225411, -175.85224441, -175.77015821, -175.79199091,
#        -175.80284759, -175.79078985]), 88: array([-175.02341577, -175.07971885, -175.09535717, -175.09971254,
#        -175.06069134, -175.11278166]), 68: array([-175.32786561, -175.37822877, -175.38575845, -175.38939129,
#        -175.32062635, -175.33471621]), 168: array([-174.39671835, -174.39786686, -174.32735421, -174.36384952,
#        -174.35681707, -174.35353691]), 468: array([-178.91203955, -178.87464075, -178.93034645, -178.92579121,
#        -178.03815345, -176.1218821 ]), 408: array([-113.69862222, -121.65927829, -113.47473016, -120.83871383,
#        -113.73133928, -113.81768864]), 416: array([-94.28193794, -94.21360362, -94.28933466, -94.24462801,
#        -94.06640065, -94.31189708]), 316: array([-90.91839591, -90.90536   , -90.52867049, -93.19459333,
#        -91.23095066, -91.06604471]), 216: array([-77.91764746, -77.9113884 , -78.16372764, -77.92268159,
#        -77.95969643, -77.93907306]), 453: array([-171.59872097, -171.61361616, -171.65056354, -171.61597058,
#        -171.58825087, -171.61622988]), 76: array([-104.58324715, -104.64424007, -104.60203777, -104.60150012,
#        -104.62812202, -104.56427224]), 313: array([-188.86102536, -187.1290881 , -188.64864456, -187.1541697 ,
#        -186.52098455, -191.48754092]), 413: array([-191.43759809, -198.80859589, -195.69439364, -194.53280947,
#        -191.5340041 , -195.37147628]), 56: array([-104.05525023, -103.40199898, -103.50093936, -108.99833305,
#        -105.50336426, -105.23995658]), 176: array([-104.1464728 , -104.17062237, -104.16160391, -104.17026054,
#        -105.77319572, -103.96242662]), 156: array([-101.78928738,  -99.75302838, -103.44029167,  -94.64981262,
#        -104.91609539, -101.12145026]), 356: array([-87.63263319, -85.25856073, -88.42169277, -85.2524294 ,
#        -85.2608097 , -85.25687594]), 456: array([-85.46187071, -85.45588868, -85.48482139, -87.79017792,
#        -87.68142149, -85.52114281]), 436: array([-103.86802546, -106.69814379, -102.99045881, -101.25076389,
#         -89.38202822, -101.72388971]), 336: array([-85.50303541, -86.61808237, -85.58682771, -87.36054125,
#        -88.81224637, -85.53261025]), 116: array([ -78.74034632,  -71.83831547,  -73.00171649,  -75.24170208,
#        -105.78032052,  -73.27943411])})

# %% [markdown]
# ## Goal 1 - Beat Random
#
# As an initial goal, come up with an agent/policy that does better than random.
# And more specifically, try to at least have a positive score (>0) average.
#
# This game is discrete, and so you can use the Q-learning approach and build a
# matrix of states by actions populated with expected rewards. This approach
# should work well and it is suggested you start with it.

# %% [markdown]
# ## Goal 2 - Beat Basic Q-learning
#
# Once you've got an initial Q-learning approach working, you should try to
# improve it via hyperparameter optimization. A score (average performance across
# many games) generated without optimizing hyperparameters that you should try to
# beat: `8.467`
#
# You should be able to do better without having to use different techniques (i.e.
# just with hyperparameter optimization).

# %% [markdown]
# ## Goal 3 - Beat Optimized Q-learning (stretch)
#
# Now the sky's the limit - or rather, the best possible performance in Taxi. With
# the default environment, optimized Q-learning has achieved an average score of
# `9.423`. See if you can get in that range, or possibly even beat it, by
# employing alternative techniques.
#
# What is an alternative technique? It's anything that maps from environment state
# to action - Q-learning achieves this by populating a Q-table, but any model that
# can take the environment state and possible action as input and give predicted
# reward as output can serve the same purpose. And the Gym environment object
# gives us a simulator perfect for generating arbitrary amounts of training data
# to train such a model.
#
# The true optimal performance in Taxi is probably not much more than the
# optimized Q-learning score - the score certainly has to be less than 20 as the
# taxi must always take at least some steps to achieve the task.
#
# If you get this far, feel free to share the best score you get, and see how your
# classmates are doing. Good luck!
